# %%
# Imports
import os
import time
import csv
import datetime
import requests
import json
import pandas as pd


pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Get data function

# %% [markdown]
# TODO: Make get_price function run off a list of coins
# TODO: Write header only once, on first loop

# %%
def get_price():
    ### Returns price & social media scores for list of coins
    NaN = 'NaN'
    # bitcoin price
    _1 = requests.get('https://min-api.cryptocompare.com/data/pricemultifull?fsyms=BTC&tsyms=USD')

    # bitcoin social media metrics
    _2 = requests.get('https://www.cryptocompare.com/api/data/socialstats/?id=1182')

    # ethereum price
    _3 = requests.get('https://min-api.cryptocompare.com/data/pricemultifull?fsyms=ETH&tsyms=USD')

    # ethereum social media metrics
    _4 = requests.get('https://www.cryptocompare.com/api/data/socialstats/?id=7605')

    # IOTA price
    _5 = requests.get('https://min-api.cryptocompare.com/data/pricemultifull?fsyms=IOT&tsyms=USD')

    # IOTA social media metrics
    _6 = requests.get('https://www.cryptocompare.com/api/data/socialstats/?id=127356')

     # bitcoin cash price
    _7 = requests.get('https://min-api.cryptocompare.com/data/pricemultifull?fsyms=BCH&tsyms=USD')

     # bitcoin cash social media metrics
    _8 = requests.get('https://www.cryptocompare.com/api/data/socialstats/?id=202330')

    # litecoin price
    _9 = requests.get('https://min-api.cryptocompare.com/data/pricemultifull?fsyms=LTC&tsyms=USD')

    # litecoin social media metrics
    _10 = requests.get('https://www.cryptocompare.com/api/data/socialstats/?id=29758')

    if _1.status_code == 200: # if the first call works load the jsons
        try:
            _btc_price = json.loads(_1.content)
            _btc_sms = json.loads(_2.content)
            _eth_price = json.loads(_3.content)
            _eth_sms = json.loads(_4.content)
            _iot_price = json.loads(_5.content)
            _iot_sms = json.loads(_6.content)
            _bch_price = json.loads(_7.content)
            _bch_sms = json.loads(_8.content)
            _ltc_price = json.loads(_9.content)
            _ltc_sms = json.loads(_10.content)
            
            # Build DataFrame structure
            global df
            df = pd.DataFrame(columns=['time',
                     'BTC_Price', 'BTC_Total', 'BTC_CryptoCompare', 'BTC_Twitter', 'BTC_Reddit', 'BTC_Facebook', 'BTC_GitHub',
                     'ETH_Price', 'ETH_Total', 'ETH_CryptoCompare', 'ETH_Twitter', 'ETH_Reddit', 'ETH_Facebook', 'ETH_GitHub',
                     'IOT_Price', 'IOT_Total', 'IOT_CryptoCompare', 'IOT_Twitter', 'IOT_Reddit', 'IOT_Facebook', 'IOT_GitHub',
                     'BCH_Price', 'BCH_Total', 'BCH_CryptoCompare', 'BCH_Twitter', 'BCH_Reddit', 'BCH_Facebook', 'BCH_GitHub',
                     'LTC_Price', 'LTC_Total', 'LTC_CryptoCompare', 'LTC_Twitter', 'LTC_Reddit', 'LTC_Facebook', 'LTC_GitHub'])           


            # Append data to dataframe
            df = df.append({'time': time.strftime("%Y_%m%d_%H%M%S"),
                                 'BTC_Price': _btc_price['DISPLAY']['BTC']['USD']['PRICE'],
                                 'BTC_Total': _btc_sms['Data']['General']['Points'],
                                 'BTC_CryptoCompare': _btc_sms['Data']['CryptoCompare']['Points'],
                                 'BTC_Twitter': _btc_sms['Data']['Twitter']['Points'],
                                 'BTC_Reddit': _btc_sms['Data']['Reddit']['Points'],
                                 'BTC_Facebook': _btc_sms['Data']['Facebook']['Points'],
                                 'BTC_GitHub': _btc_sms['Data']['CodeRepository']['Points'],

                                 'ETH_Price': _eth_price['DISPLAY']['ETH']['USD']['PRICE'], 
                                 'ETH_Total': _eth_sms['Data']['General']['Points'], 
                                 'ETH_CryptoCompare': _eth_sms['Data']['CryptoCompare']['Points'], 
                                 'ETH_Twitter': _eth_sms['Data']['Twitter']['Points'], 
                                 'ETH_Reddit': _eth_sms['Data']['Reddit']['Points'], 
                                 'ETH_Facebook': _eth_sms['Data']['Facebook']['Points'], 
                                 'ETH_GitHub': _eth_sms['Data']['CodeRepository']['Points'],

                                 'IOT_Price': _iot_price['DISPLAY']['IOT']['USD']['PRICE'], 
                                 'IOT_Total': _iot_sms['Data']['General']['Points'], 
                                 'IOT_CryptoCompare': _iot_sms['Data']['CryptoCompare']['Points'], 
                                 'IOT_Twitter': _iot_sms['Data']['Twitter']['Points'], 
                                 'IOT_Reddit': _iot_sms['Data']['Reddit']['Points'], 
                                 'IOT_Facebook': _iot_sms['Data']['Facebook']['Points'], 
                                 'IOT_GitHub': _iot_sms['Data']['CodeRepository']['Points'],

                                 'BCH_Price': _bch_price['DISPLAY']['BCH']['USD']['PRICE'], 
                                 'BCH_Total':  _bch_sms['Data']['General']['Points'], 
                                 'BCH_CryptoCompare':  _bch_sms['Data']['CodeRepository']['Points'], 
                                 'BCH_Twitter':  _bch_sms['Data']['Twitter']['Points'], 
                                 'BCH_Reddit':  _bch_sms['Data']['Reddit']['Points'], 
                                 'BCH_Facebook':  _bch_sms['Data']['Facebook']['Points'], 
                                 'BCH_GitHub':  _bch_sms['Data']['CodeRepository']['Points'],

                                 'LTC_Price': _ltc_price['DISPLAY']['LTC']['USD']['PRICE'], 
                                 'LTC_Total': _ltc_sms['Data']['CodeRepository']['Points'], 
                                 'LTC_CryptoCompare': _ltc_sms['Data']['CodeRepository']['Points'], 
                                 'LTC_Twitter': _ltc_sms['Data']['CodeRepository']['Points'], 
                                 'LTC_Reddit': _ltc_sms['Data']['CodeRepository']['Points'], 
                                 'LTC_Facebook': _ltc_sms['Data']['CodeRepository']['Points'], 
                                 'LTC_GitHub': _ltc_sms['Data']['CodeRepository']['Points']}, ignore_index=True)


            with open('../../coins/output/crypto-ticker.csv', 'a') as csvfile:
                df.to_csv(csvfile, header=False)

        except:
            print("Error")
    else:
        print("No connection")

# %%
# , header=False
get_price()

# %% [markdown]
# # Timed function

# %%
from datetime import datetime
import time
import os

from apscheduler.schedulers.background import BackgroundScheduler


def tick():
    print('Tick! The time is: %s' % datetime.now())
    get_price()


if __name__ == '__main__':
    scheduler = BackgroundScheduler()
    scheduler.add_job(tick, 'interval', seconds=15)
    scheduler.start()
    print('Press Ctrl+{0} to exit'.format('Break' if os.name == 'nt' else 'C'))
    
    try:
        # This is here to simulate application activity (which keeps the main thread alive).
        while True:
            time.sleep(10)
    except (KeyboardInterrupt, SystemExit):
in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='min-api.cryptocompare.com', port=443): Max retries exceeded with url: /data/pricemultifull?fsyms=LTC&tsyms=USD (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f2cfa8c69e8>: Failed to establish a new connection: [Errno 110] Connection timed out',))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-42c69e3c3dd7>", line 10, in tick
#     get_price()
#   File "<ipython-input-2-adfa5ef3d04f>", line 29, in get_price
#     _9 = requests.get('https://min-api.cryptocompare.com/data/pricemultifull?fsyms=LTC&tsyms=USD')
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/requests/api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/requests/api.py", line 58, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/requests/sessions.py", line 508, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/requests/sessions.py", line 618, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/requests/adapters.py", line 508, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='min-api.cryptocompare.com', port=443): Max retries exceeded with url: /data/pricemultifull?fsyms=LTC&tsyms=USD (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f2cfa8c69e8>: Failed to establish a new connection: [Errno 110] Connection timed out',))
# Tick! The time is: 2018-02-28 14:13:16.845266
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:13:31 CST)" skipped: maximum number of running instances reached (1)
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:13:46 CST)" skipped: maximum number of running instances reached (1)
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:14:01 CST)" skipped: maximum number of running instances reached (1)
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:14:16 CST)" skipped: maximum number of running instances reached (1)
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:14:31 CST)" skipped: maximum number of running instances reached (1)
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:14:46 CST)" skipped: maximum number of running instances reached (1)
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:15:01 CST)" skipped: maximum number of running instances reached (1)
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:15:16 CST)" skipped: maximum number of running instances reached (1)
# Job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:15:31 CST)" raised an exception
# Traceback (most recent call last):
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/connection.py", line 141, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/util/connection.py", line 83, in create_connection
#     raise err
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/util/connection.py", line 73, in create_connection
#     sock.connect(sa)
# TimeoutError: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/connectionpool.py", line 601, in urlopen
#     chunked=chunked)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/connectionpool.py", line 346, in _make_request
#     self._validate_conn(conn)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/connectionpool.py", line 850, in _validate_conn
#     conn.connect()
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/connection.py", line 284, in connect
#     conn = self._new_conn()
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/connection.py", line 150, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x7f2cfa8ed588>: Failed to establish a new connection: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/requests/adapters.py", line 440, in send
#     timeout=timeout
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/connectionpool.py", line 639, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/util/retry.py", line 388, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='min-api.cryptocompare.com', port=443): Max retries exceeded with url: /data/pricemultifull?fsyms=BTC&tsyms=USD (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f2cfa8ed588>: Failed to establish a new connection: [Errno 110] Connection timed out',))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-42c69e3c3dd7>", line 10, in tick
#     get_price()
#   File "<ipython-input-2-adfa5ef3d04f>", line 5, in get_price
#     _1 = requests.get('https://min-api.cryptocompare.com/data/pricemultifull?fsyms=BTC&tsyms=USD')
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/requests/api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/requests/api.py", line 58, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/requests/sessions.py", line 508, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/requests/sessions.py", line 618, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/requests/adapters.py", line 508, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='min-api.cryptocompare.com', port=443): Max retries exceeded with url: /data/pricemultifull?fsyms=BTC&tsyms=USD (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f2cfa8ed588>: Failed to establish a new connection: [Errno 110] Connection timed out',))
# Tick! The time is: 2018-02-28 14:15:31.845255
# Tick! The time is: 2018-02-28 14:15:46.844624
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:16:01 CST)" skipped: maximum number of running instances reached (1)
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:16:16 CST)" skipped: maximum number of running instances reached (1)
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:16:31 CST)" skipped: maximum number of running instances reached (1)
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:16:46 CST)" skipped: maximum number of running instances reached (1)
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:17:01 CST)" skipped: maximum number of running instances reached (1)
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:17:16 CST)" skipped: maximum number of running instances reached (1)
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:17:31 CST)" skipped: maximum number of running instances reached (1)
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:17:46 CST)" skipped: maximum number of running instances reached (1)
# Job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:18:01 CST)" raised an exception
# Traceback (most recent call last):
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/connection.py", line 141, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/util/connection.py", line 83, in create_connection
#     raise err
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/util/connection.py", line 73, in create_connection
#     sock.connect(sa)
# TimeoutError: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/connectionpool.py", line 601, in urlopen
#     chunked=chunked)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/connectionpool.py", line 346, in _make_request
#     self._validate_conn(conn)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/connectionpool.py", line 850, in _validate_conn
#     conn.connect()
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/connection.py", line 284, in connect
#     conn = self._new_conn()
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/connection.py", line 150, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x7f2cfa8d79b0>: Failed to establish a new connection: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/requests/adapters.py", line 440, in send
#     timeout=timeout
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/connectionpool.py", line 639, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/util/retry.py", line 388, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='min-api.cryptocompare.com', port=443): Max retries exceeded with url: /data/pricemultifull?fsyms=IOT&tsyms=USD (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f2cfa8d79b0>: Failed to establish a new connection: [Errno 110] Connection timed out',))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-42c69e3c3dd7>", line 10, in tick
#     get_price()
#   File "<ipython-input-2-adfa5ef3d04f>", line 17, in get_price
#     _5 = requests.get('https://min-api.cryptocompare.com/data/pricemultifull?fsyms=IOT&tsyms=USD')
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/requests/api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/requests/api.py", line 58, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/requests/sessions.py", line 508, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/requests/sessions.py", line 618, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/requests/adapters.py", line 508, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='min-api.cryptocompare.com', port=443): Max retries exceeded with url: /data/pricemultifull?fsyms=IOT&tsyms=USD (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f2cfa8d79b0>: Failed to establish a new connection: [Errno 110] Connection timed out',))
# Tick! The time is: 2018-02-28 14:18:01.845275
# Tick! The time is: 2018-02-28 14:18:16.844633
# Tick! The time is: 2018-02-28 14:18:31.844622
# Tick! The time is: 2018-02-28 14:18:46.844623
# Tick! The time is: 2018-02-28 14:19:01.844629
# Tick! The time is: 2018-02-28 14:19:16.844627
# Tick! The time is: 2018-02-28 14:19:31.844628
# Tick! The time is: 2018-02-28 14:19:46.844613
# Tick! The time is: 2018-02-28 14:20:01.844627
# Tick! The time is: 2018-02-28 14:20:16.844624
# Tick! The time is: 2018-02-28 14:20:31.844622
# Tick! The time is: 2018-02-28 14:20:46.844623
# Tick! The time is: 2018-02-28 14:21:01.844629
# Tick! The time is: 2018-02-28 14:21:16.844632
# Tick! The time is: 2018-02-28 14:21:31.844623
# Tick! The time is: 2018-02-28 14:21:46.844621
# Tick! The time is: 2018-02-28 14:22:01.844630
# Tick! The time is: 2018-02-28 14:22:16.844622
# Tick! The time is: 2018-02-28 14:22:31.844630
# Tick! The time is: 2018-02-28 14:22:46.844628
# Tick! The time is: 2018-02-28 14:23:01.844629
# Tick! The time is: 2018-02-28 14:23:16.844593
# Tick! The time is: 2018-02-28 14:23:31.844574
# Tick! The time is: 2018-02-28 14:23:46.844603
# Tick! The time is: 2018-02-28 14:24:01.844629
# Tick! The time is: 2018-02-28 14:24:16.844623
# Tick! The time is: 2018-02-28 14:24:31.844626
# Tick! The time is: 2018-02-28 14:24:46.844626
# Tick! The time is: 2018-02-28 14:25:01.844628
# Tick! The time is: 2018-02-28 14:25:16.844623
# Tick! The time is: 2018-02-28 14:25:31.844624
# Tick! The time is: 2018-02-28 14:25:46.844623
# Tick! The time is: 2018-02-28 14:26:01.844633
# Tick! The time is: 2018-02-28 14:26:16.844629
# Tick! The time is: 2018-02-28 14:26:31.844651
# Tick! The time is: 2018-02-28 14:26:46.844636
# Tick! The time is: 2018-02-28 14:27:01.844632
# Tick! The time is: 2018-02-28 14:27:16.844614
# Tick! The time is: 2018-02-28 14:27:31.844627
# Tick! The time is: 2018-02-28 14:27:46.844633
# Tick! The time is: 2018-02-28 14:28:01.844632
# Tick! The time is: 2018-02-28 14:28:16.844625
# Tick! The time is: 2018-02-28 14:28:31.844631
# Tick! The time is: 2018-02-28 14:28:46.844626
# Tick! The time is: 2018-02-28 14:29:01.844628
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:29:16 CST)" skipped: maximum number of running instances reached (1)
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:29:31 CST)" skipped: maximum number of running instances reached (1)
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:29:46 CST)" skipped: maximum number of running instances reached (1)
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:30:01 CST)" skipped: maximum number of running instances reached (1)
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:30:16 CST)" skipped: maximum number of running instances reached (1)
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:30:31 CST)" skipped: maximum number of running instances reached (1)
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:30:46 CST)" skipped: maximum number of running instances reached (1)
# Execution of job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:31:01 CST)" skipped: maximum number of running instances reached (1)
# Job "tick (trigger: interval[0:00:15], next run at: 2018-02-28 14:31:16 CST)" raised an exception
# Traceback (most recent call last):
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/connection.py", line 141, in _new_conn
#     (self.host, self.port), self.timeout, **extra_kw)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/util/connection.py", line 83, in create_connection
#     raise err
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/util/connection.py", line 73, in create_connection
#     sock.connect(sa)
# TimeoutError: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/connectionpool.py", line 601, in urlopen
#     chunked=chunked)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/connectionpool.py", line 346, in _make_request
#     self._validate_conn(conn)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/connectionpool.py", line 850, in _validate_conn
#     conn.connect()
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/connection.py", line 284, in connect
#     conn = self._new_conn()
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/connection.py", line 150, in _new_conn
#     self, "Failed to establish a new connection: %s" % e)
# urllib3.exceptions.NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x7f2cfa903978>: Failed to establish a new connection: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/requests/adapters.py", line 440, in send
#     timeout=timeout
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/connectionpool.py", line 639, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/urllib3/util/retry.py", line 388, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='min-api.cryptocompare.com', port=443): Max retries exceeded with url: /data/pricemultifull?fsyms=IOT&tsyms=USD (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f2cfa903978>: Failed to establish a new connection: [Errno 110] Connection timed out',))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/apscheduler/executors/base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "<ipython-input-4-42c69e3c3dd7>", line 10, in tick
#     get_price()
#   File "<ipython-input-2-adfa5ef3d04f>", line 17, in get_price
#     _5 = requests.get('https://min-api.cryptocompare.com/data/pricemultifull?fsyms=IOT&tsyms=USD')
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/requests/api.py", line 72, in get
#     return request('get', url, params=params, **kwargs)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/requests/api.py", line 58, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/requests/sessions.py", line 508, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/requests/sessions.py", line 618, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/marc/anaconda3/envs/catalyst/lib/python3.6/site-packages/requests/adapters.py", line 508, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host